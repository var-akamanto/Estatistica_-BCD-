# %%
import pandas as pd
import openpyxl

path = "C:/Users/pedro-admin/Desktop/ciencia-de-dados-furb/Primeiro-Semestre/Estatistica/Estatistica_-BCD-/Dados_CalourosBCD.xlsx"
df = pd.read_excel(path)
df['Qual linguagem você já utilizou?'].head(100)
# Out:
# 0                                        SQL, Python, R
# 1                                                  Java
# 2                                                    C#
# 3                                           Java script
# 4                            Java, SQL, CSS, Javascript
# 5                                                Python
# 6                                                    C#
# 7                                      Java, Javascript
# 8                                           Python, SQL
# 9                         Java, Python, JavaScript, SQL
# 10                                                  NaN
# 11                                                  NaN
# 12                                                 Java
# 13                       python, java, java script, sql
# 14                                                  NaN
# 15                                  Java, SQL e python
# 16                                             Java,PHP
# 17                                                  NaN
# 18                                                 Java
# 19                                               Python
# 20                            C#, flutter, Dart, C, C++
# 21                           Java, Flutter, SQL, Python
# 22                                               Phyton
# 23                                         Python, Rust
# 24                                                  NaN
# 25                                 C, Java, Python, SQL
# 26                                         Vibe coding
# 27                                                  NaN
# 28                                                  NaN
# 29                                               Python
# 30    Java, JavaScript, JSP em geral, HTML/CSS, Flut...
# 31                            Phyton, C, Java, Assembly
# 32                                                  NaN
# 33                                                  NaN
# 34                   Python, HTML, JavaScript, CSS, SQL
# 35                                                  NaN
# 36                                                  NaN
# 37                                               Python
# 38                                          Python, SQL
# 39                                               Python
# 40                                          Javascript
# 41                                                Java
# 42                                                 Java
# 43                                     Programação em c
# 44                                                   C#
# 45               Java script, Java, Python, C#, Delphi
# 46                             Java, SQL, HTML, CSS, JS
# 47                                                  NaN
# 48                                                 Java
# 49                                            ABAP, SQL
# 50                                   Python, HTML e CSS
# 51                                              Python
# 52                                              Python
# 53                                               Python
# 54                        C#; C++; Java; Python; html;
# 55                                HTML, CSS, Javascript
# Name: Qual linguagem você já utilizou?, dtype: str
